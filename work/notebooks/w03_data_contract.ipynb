# %% [markdown]
# # ML-04 — Search Intelligence Data Contract
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Unit of analysis + time window
#
# *One row = one what, over which dates? State it, then verify it below.*

# %% [markdown]
# Unit of Analysis
#
# One row represents one content page observed during a specific month.
#
# For this analysis, I will use data from March 2026 as the working time window. I will use the mid-panel month to develop and verify the lane rather than the final June 2026 month, which is reserved as a sealed outcome/test window.

# %% [markdown]
# ## 2. Fields: feature / label / context / excluded
#
# *Sort every field you plan to touch into these four buckets. Excluded needs a why.*

# %% [markdown]
# Fields
#
# Features: search volume, competition level, CPC, CTR, content age, impressions.
#
# Label: trend direction, used as a proxy for whether a content page may need attention.
#
# Context: content type, main search intent, and other page/search characteristics that help interpret the page's performance.
#
# Excluded: content ID and client ID, because they identify records but do not provide useful predictive information for deciding which pages should be prioritized for refresh.

# %% [markdown]
# ## 3. Verify it with queries (grain, counts, missing values, windows)
#
# *Every claim above gets a query cell here. A contract claim without a query next to it is a guess.*

# %%
import pandas as pd

df = pd.read_csv("../../data/raw/content_refresh_anonymized.csv")

print("Dataset loaded:", df.shape)
# Out:
# Dataset loaded: (30000, 44)

# %%
print(df.columns.tolist())
print(df.dtypes)
# Out:
# ['content_id', 'client_id', 'search_volume', 'competition', 'competition_level', 'cpc', 'content_type', 'main_intent', 'word_count', 'char_count', 'provider_used', 'model_used', 'impressions_90d', 'clicks_90d', 'pageviews_90d', 'sessions_90d', 'users_90d', 'engaged_sessions_90d', 'ai_sessions_90d', 'scroll_events_90d', 'days_with_impressions', 'days_with_sessions', 'impressions_last_30d', 'clicks_last_30d', 'sessions_last_30d', 'impressions_prev_30d', 'clicks_prev_30d', 'sessions_prev_30d', 'content_age_days', 'age_tier', 'age_tier_order', 'days_since_last_update', 'freshness_tier', 'word_count_tier', 'char_count_tier', 'ctr', 'avg_position', 'engagement_rate', 'scroll_rate', 'ai_traffic_pct', 'impression_tier', 'position_tier', 'trend_direction', 'trend_pct']
# content_id                    str
# client_id                     str
# search_volume             float64
# competition               float64
# competition_level             str
# cpc                       float64
# ...

# %% [markdown]
# ## 4. Data limits
#
# *What can this data never tell you? Unbalanced history, GSC-only early rows, window overlaps.*

# %% [markdown]
# Data Limits
#
# One limitation is that the data may have uneven history across content pages. Some pages may have fewer historical observations or earlier rows that depend mainly on Google Search Console data.
#
# The March 2026 slice also cannot tell us whether a refresh will definitely cause better future search performance. It can only provide evidence for prioritizing pages for review.
#
# I also exclude the final June 2026 month from development because it is the sealed outcome/test window.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
